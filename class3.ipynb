# %%
'hello' > 'bye'
# Out:
# True

# %%
'bye' < 'hye'
# Out:
# True

# %%
'z' < 'abc'
# Out:
# False

# %%
temp = ('hello python' if 4 < 10 else 9)

# %%
print(temp)
# Out:
# hello python

# %%
'''while (any expression):
    temp = 
    hjfdsh
    hsajhf
    hfjsadh
    hfjds '''
# Out:
# 'while (any expression):\n    temp = \n    hjfdsh\n    hsajhf\n    hfjsadh\n    hfjds '

# %%
def first():
    print('first function')

# %%
first()
# Out:
# first function

# %%
def second():
    print('second called')
    return 5

# %%
second()
# Out:
# second called
# 5

# %%
print(second())
# Out:
# second called
# 5

# %%
t = second()
print('t is:', t , type(t))
# Out:
# second called
# t is: 5 <class 'int'>

# %%
def third():
    print('third function')
    print('hello python')

# %%
t = third()
# Out:
# third function
# hello python

# %%
print(t)
# Out:
# None

# %%
def print_welcom_message():
    print('-'*40)
    print('hello world pythob')
    print('0'*40)

# %%
print_welcom_message()
# Out:
# ----------------------------------------
# hello world pythob
# 0000000000000000000000000000000000000000

# %%
def square_of(x):
    return x**2

# %%
square_of(10)
# Out:
# 100

# %%
square_of(-2)
# Out:
# 4

# %%
square_of(0)
# Out:
# 0

# %%
square_of()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-a78a4fd5dc86> in <module>()
# ----> 1 square_of()
#
# TypeError: square_of() missing 1 required positional argument: 'x'

# %%
some_function()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-6a01c81cb036> in <module>()
# ----> 1 some_function()
#
# NameError: name 'some_function' is not defined

# %%
def greet_me_again(name = 'unknown'):
    print('hello', name)

# %%
greet_me_again()
# Out:
# hello unknown

# %%
greet_me_again('python')
# Out:
# hello python

# %%
def exponent(x,y):
    return x**y

# %%
exponent()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-a203cba23490> in <module>()
# ----> 1 exponent()
#
# TypeError: exponent() missing 2 required positional arguments: 'x' and 'y'

# %%
exponent(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-fbd97b79a1b1> in <module>()
# ----> 1 exponent(2)
#
# TypeError: exponent() missing 1 required positional argument: 'y'

# %%
exponent(2,3)
# Out:
# 8

# %%
exponent(2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-6ad9db3ff6fb> in <module>()
# ----> 1 exponent(2,3,4)
#
# TypeError: exponent() takes 2 positional arguments but 3 were given

# %%
print('hello python' , end = "\t")
print('hello python')
# Out:
# hello python	hello python

# %%
print('hello', 'python', 'is' , 'good', sep="***")
# Out:
# hello***python***is***good

# %%
abs(2)
# Out:
# 2

# %%
abs(-3)
# Out:
# 3

# %%
help(abs)
# Out:
# Help on built-in function abs in module builtins:
#
# abs(x, /)
#     Return the absolute value of the argument.

# %%
hex(55)
# Out:
# '0x37'

# %%
bin(5)
# Out:
# '0b101'

# %%
oct(10)
# Out:
# '0o12'

# %%
bool(None)
# Out:
# False

# %%
round(3.4)
# Out:
# 3

# %%
round(5.6)
# Out:
# 6

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(...)
#     round(number[, ndigits]) -> number
#
#     Round a number to a given precision in decimal digits (default 0 digits).
#     This returns an int when called with one argument, otherwise the
#     same type as the number. ndigits may be negative.

# %%
pow(2,3)
# Out:
# 8

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65

# %%
chr(65)
# Out:
# 'A'

# %%
min('4345')
# Out:
# '3'

# %%
max('498')
# Out:
# '9'

# %%
max([1,2,3,4,5])
# Out:
# 5

# %% [markdown]
# # String Methods

# %%
'hello python'.capitalize()
# Out:
# 'Hello python'

# %%
'hello python'.count('l')
# Out:
# 2

# %%
'hello python'.find('p')
# Out:
# 6

# %%
'hello python'.find('z')
# Out:
# -1

# %%
'hello python'.endswith('a')
# Out:
# False

# %%
'hello python'.endswith('on')
# Out:
# True

# %%
'hello python'.startswith('hel')
# Out:
# True

# %%
'hello python'.isalpha()
# Out:
# False

# %%
'hello'.isalpha()
# Out:
# True

# %%
'468293748'.isdigit()
# Out:
# True

# %%
'5937hf'.isdigit()
# Out:
# False

# %%
'fhdjshf'.islower()
# Out:
# True

# %%
'fjdGRS'.islower()
# Out:
# False

# %%
'GSDGSD'.isupper()
# Out:
# True

# %%
'fndksnf'.isupper()
# Out:
# False

# %%
'hello python'.replace('h', 'j')
# Out:
# 'jello pytjon'

# %%
'hello pYTHON'.swapcase()
# Out:
# 'HELLO Python'

# %%
'hello puthon'.title()
# Out:
# 'Hello Puthon'

# %%
'fjkdsjflsj'.isspace()
# Out:
# False

# %%
'    n  '.isspace()
# Out:
# False

# %%
'      '.isspace()
# Out:
# True

# %% [markdown]
# # Scopes

# %%
x = 100
if True:
    print(x)
# Out:
# 100

# %%
x = 100
if False:
    x = 1
    print(x)
print(x)
# Out:
# 100

# %%
n = 10
def fun():
    print(n)

# %%
fun()
# Out:
# 10

# %%
x = 100
def fun2():
    x = 5
    print(x)
fun2()
print(x)
# Out:
# 5
# 100

# %%
if True if True else 'h':
    print('wow')
# Out:
# wow
