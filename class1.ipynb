# %%
2+2
# Out:
# 4

# %%
print('hello world')
# Out:
# hello world

# %%
x = 10

# %%
print(x)
# Out:
# 10

# %%
x = 'hello'

# %%
print(x)
# Out:
# hello

# %%
type(5)
# Out:
# int

# %%
type(1.2)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type('hello')
# Out:
# str

# %%
type(None)
# Out:
# NoneType

# %%
del = 5
# Out:
#   File "<ipython-input-12-d4a45a40a45c>", line 1
#     del = 5
#         ^
# SyntaxError: invalid syntax

# %%
2 + 4
# Out:
# 6

# %%
2 + 1.5
# Out:
# 3.5

# %%
1.5 + 1.5
# Out:
# 3.0

# %%
5 + 'hello'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-73f2ed682183> in <module>()
# ----> 1 5 + 'hello'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
5.1 + 'helo'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-381e397f66b9> in <module>()
# ----> 1 5.1 + 'helo'
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
'hello' + 'python'
# Out:
# 'hellopython'

# %%
2 - 3
# Out:
# -1

# %%
'hello' - 'python'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-7432b740be45> in <module>()
# ----> 1 'hello' - 'python'
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
4 - 1.3
# Out:
# 2.7

# %%
3*4
# Out:
# 12

# %%
2*1.5
# Out:
# 3.0

# %%
'hello'*3
# Out:
# 'hellohellohello'

# %%
2**3
# Out:
# 8

# %%
'hello'**3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-f4c9d8c56d6a> in <module>()
# ----> 1 'hello'**3
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
5/2
# Out:
# 2.5

# %%
5/5
# Out:
# 1.0

# %%
5//2
# Out:
# 2

# %%
1.1 + 1.1 + 1.1
# Out:
# 3.3000000000000003

# %%
5 > 10
# Out:
# False

# %%
10 == 5
# Out:
# False

# %%
t = 1.4

# %%
int(t)
# Out:
# 1

# %%
float(5)
# Out:
# 5.0

# %%
str(1)
# Out:
# '1'

# %%
float(1.4)
# Out:
# 1.4

# %%
g = 10.5

# %%
type(g)
# Out:
# float

# %%
y = int(g)

# %%
type(y)
# Out:
# int

# %%
int('fjklsdfll')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-aa100359e04f> in <module>()
# ----> 1 int('fjklsdfll')
#
# ValueError: invalid literal for int() with base 10: 'fjklsdfll'

# %%
int('4628164')
# Out:
# 4628164

# %%
5 > 10 or 10 < 1000
# Out:
# True

# %%
5 > 10 and 5
# Out:
# False

# %%
0 and 5 > 10
# Out:
# 0

# %%
0/1 or 0.000 or False
# Out:
# False

# %%
50 or 0.1
# Out:
# 50

# %%
bool(-12)
# Out:
# True

# %%
0/1
# Out:
# 0.0

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-56-9e1622b385b6> in <module>()
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %%
0/1 and 1/0
# Out:
# 0.0

# %%
0/1 and fjdksjfkdjksjfk
# Out:
# 0.0

# %%
5 | 3
# Out:
# 7

# %%
2*(3-1)
# Out:
# 4

# %%
5-(3-1)
# Out:
# 3

# %%
# This is a comment

# %%
t = 'hello'

# %%
y = "hello"

# %%
"I can't do this"
# Out:
# "I can't do this"

# %%
type(5 + 2j)
# Out:
# complex

# %%
temp = 'hello'

# %%
len(temp)
# Out:
# 5

# %%
'hello'[0]
# Out:
# 'h'

# %%
'hello'[3]
# Out:
# 'l'

# %%
'hello'[4]
# Out:
# 'o'

# %%
'hello'[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-72-cc8bec449e3d> in <module>()
# ----> 1 'hello'[10]
#
# IndexError: string index out of range

# %%
'hello'[-1]
# Out:
# 'o'

# %%
'hello python'[2:5]
# Out:
# 'llo'

# %%
'hello python'[:5]
# Out:
# 'hello'

# %%
'hello python'[3:]
# Out:
# 'lo python'

# %%
'hello python'[:]
# Out:
# 'hello python'

# %%
'hello pytjhon'[2:40]
# Out:
# 'llo pytjhon'

# %%
'hello' 'python'
# Out:
# 'hellopython'

# %%
'hello' + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-c9c9952ff2b4> in <module>()
# ----> 1 'hello' + 3
#
# TypeError: must be str, not int

# %%
'hello' - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-61ba53b7104f> in <module>()
# ----> 1 'hello' - 5
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
'hello' * 3
# Out:
# 'hellohellohello'

# %%
'hello' /3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-3f2f7256cc6e> in <module>()
# ----> 1 'hello' /3
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
0b101
# Out:
# 5

# %%
0o10
# Out:
# 8

# %%
0x10
# Out:
# 16

# %%
3e10
# Out:
# 30000000000.0

# %%
3e-3
# Out:
# 0.003

# %%
t = input('Enter a digit')
# Out:
# Enter a digit500

# %%
print(t)
# Out:
# 45

# %%
type(t)
# Out:
# str
